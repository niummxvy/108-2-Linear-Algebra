# %%
 # %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.sin(np.linspace(0, 100, 25))
y = np.cos(x) / np.sin(x)

plt.plot(x)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %%
plt.scatter(x, y)

# %%
plt.plot(y)

# %%
plt.scatter(y, x)
